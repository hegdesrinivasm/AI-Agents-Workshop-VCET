# %% [markdown]
# #### 📦 Block 1 — Install Dependencies

# %%
# !pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# #### 🔧 Block 2 — Import Libraries

# %%
from strands import Agent
from strands.models.ollama import OllamaModel

# %% [markdown]
# #### 🤖 Block 3 — Initialize the Ollama Model (Gemma 4)

# %%
model = OllamaModel(
    model_id="gemma4:e4b",   # use "gemma3:27b" if you pulled the 27B variant
    host="http://localhost:11434"
)

# %% [markdown]
# #### 🛠️ Block 4 — Create a Simple Agent

# %%
agent = Agent(
    model=model,
    system_prompt="You are a helpful assistant powered by Gemma 4 running locally via Ollama."
)

# %% [markdown]
# #### 💬 Block 5 — Run a Test Query

# %%
response = agent("What is the capital of India, and give me 3 fun facts about it.")
print(response)
# Out:
# The capital of India is **New Delhi**.
#
# Here are 3 fun facts about New Delhi (and the greater Delhi area):
#
# 1. **A City of Layers:** Delhi is famous for being a physical tapestry of history. You can find remnants of the sophisticated Indus Valley Civilization (which predates recorded history), the architecture of the Mughal Empire (like the Red Fort), the British colonial structures, and hyper-modern skyscrapers, all existing side-by-side. It’s a city built upon layers of millennia.
# 2. **A Culinary Adventure:** Delhi is often lauded as one of the best food cities in the world. Its street food scene is legendary and incredibly diverse. You can find everything from fragrant, spicy *chaat* (savory snacks) to rich, creamy *parathas*, making every neighborhood a unique culinary journey.
# ...

# %% [markdown]
# #### 🔁 Block 6 — Multi-turn Conversation Test

# %%
# Turn 1
agent("My name is Srinivas. Remember this.")
# Out:
# Thank you, Srinivas. I have updated and stored that.
#
# I will remember that your name is Srinivas.
# ...

# %%
# Turn 2 — tests memory within session
response = agent("What is my name?")
# Out:
# Your name is Srinivas.

# %% [markdown]
# #### 🧰 Block 7 — Agent with a Built-in Tool (Calculator)

# %%
from strands_tools import calculator

agent_with_tools = Agent(
    model=model,
    system_prompt="You are a helpful assistant. Use tools when needed.",
    tools=[calculator]
)

response = agent_with_tools("What is 1234 * 5678?")
# Out:
# Tool #1: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 1234 * 5678         │                                                                            │
# │  │ Result    │ 7006652             │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ...
